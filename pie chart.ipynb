# %%
import matplotlib.pyplot as plt

# %matplotlib inline


sizes =[1.35, 3.40, 2.25, 1.80]
labels='engineering', 'manufacturing', 'sales', 'profit'

plt.pie(sizes,
       labels=labels)

plt.title('cost breakdown of $9microcontroller')
plt.axis('equal')

plt.show()
